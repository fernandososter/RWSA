# %%
import mne
raw = mne.io.read_raw_edf("../data/nfle8.edf", preload=True, verbose="ERROR")
raw.plot()
# Out:
# Falha ao iniciar o Kernel.
#
# Não é possível iniciar o Kernel ".venv (3.12.7) (Python 3.12.7)" devido a um tempo limite aguardando as portas serem usadas.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.

# %%
seg = raw.copy().crop(tmin=4*3600, tmax=4*3600 + 5*60)
print(seg)
seg.plot(duration=60)
